# %%
import csv
import ast
import numpy as np
import time

start = time.time()

# --- Load BB (Billboard data) ---
BB = []
with open("BB_NYC.csv", 'r') as file:
    reader = csv.DictReader(file)
    for row in reader:
        BB.append({
            'B_index': int(row['B_index']),           
            'Influence': float(row['Influence'])     
        })

# Sort billboard data by descending influence
BB.sort(key=lambda x: x['Influence'], reverse=True)
# print(BB)

# --- Load ub (User influence data) ---
ub = []
with open("new_ub.csv", 'r') as file:
    reader = csv.DictReader(file)
    for row in reader:
        row['Influenced Billboards'] = ast.literal_eval(row['Influenced Billboards'])
        ub.append(row)

# --- Load Dem (Demand values) ---
Dem = []
with open("advertiser_1.csv", 'r') as file:
    reader = csv.DictReader(file)
    for row in reader:
        Dem.append(float(row['Demand']))

# BillboardSlot class
class BillboardSlot:
    def __init__(self, idx):
        self.idx = idx
    def __repr__(self):
        return f"Slot({self.idx})"

# Convert BB to BillboardSlot objects using B_index
BS = [BillboardSlot(item['B_index']) for item in BB[:5000]]
# print("BS",BS)

# %%
# Influence function
def influence(S):
    influence_score = 0.0
    slot_ids = {s.idx if isinstance(s, BillboardSlot) else s for s in S}
    # print("slot_ids",slot_ids)
    for row in ub:
        influenced_billboards = row['Influenced Billboards']
        intersection_result = {int(key): value for key, value in influenced_billboards.items() if int(key) in slot_ids}
        product = 1.0
        # print("Intersection Result:",intersection_result)
        for value in intersection_result.values():
            # print("vlaue",value)
            
            product *= (1 - value)
            # print("product",product)
        influence_score += (1 - product)
        # print("influence_score",influence_score)
    return influence_score

# %%
def assign_top_influential(BS, Dem):
    used_slots = set()               # Track globally used slots
    Si_list = [set() for _ in Dem]   # List of selected slots per product

    index = 0  # Index into sorted BS list (assumed sorted by influence descending)

    for j in range(len(Dem)):
        demand = Dem[j]
        current_influence = 0.0

        while current_influence < demand and index < len(BS):
            slot = BS[index]
            index += 1

            if slot.idx in used_slots:
                continue  # Skip if slot already used for another product

            Si_list[j].add(slot.idx)
            current_influence = influence(Si_list[j])
            used_slots.add(slot.idx)

        # Optional: check if the demand was actually satisfied
        if current_influence < demand:
            print(f"Warning: Demand for product {j} not fully satisfied. Got {current_influence:.2f}, needed {demand:.2f}")

    return Si_list

# %%
# Run the allocation
result = assign_top_influential(BS, Dem)
total_influence = 0
# Total unique slots
all_selected = set().union(*result)
# Print per-product slot selections
for i, slots in enumerate(result):
    print(f"Product {i+1}: Selected Slots = {sorted(list(slots))}, Influence = {influence(slots):.2f}")
    total_influence += influence(slots)
# Calculate total unique slots and total influence
print("\nTotal Selected Slots (unique):", len(all_selected))
print("Total Combined Influence:", total_influence)
print("Execution time:", round(time.time() - start, 2), "seconds")
# Out:
# Product 1: Selected Slots = [9242], Influence = 28.54
# Product 2: Selected Slots = [1843], Influence = 18.00
# Product 3: Selected Slots = [1844], Influence = 18.00
# Product 4: Selected Slots = [1775], Influence = 10.00
# Product 5: Selected Slots = [9253], Influence = 9.35
# Product 6: Selected Slots = [1772], Influence = 16.00
# Product 7: Selected Slots = [1822], Influence = 16.00
# Product 8: Selected Slots = [1841], Influence = 8.00
# Product 9: Selected Slots = [1851], Influence = 8.00
# Product 10: Selected Slots = [1861], Influence = 16.00
# Product 11: Selected Slots = [1885], Influence = 16.00
# Product 12: Selected Slots = [1897], Influence = 16.00
# Product 13: Selected Slots = [1777], Influence = 9.00
# Product 14: Selected Slots = [1816], Influence = 6.00
# Product 15: Selected Slots = [1833, 1835, 1850, 1852, 1860], Influence = 9.00
# Product 16: Selected Slots = [1864], Influence = 9.00
# Product 17: Selected Slots = [1870], Influence = 3.00
# Product 18: Selected Slots = [1871], Influence = 6.00
# Product 19: Selected Slots = [1875], Influence = 9.00
# Product 20: Selected Slots = [1879], Influence = 9.00
# Product 21: Selected Slots = [1888], Influence = 6.00
# Product 22: Selected Slots = [1890, 7583], Influence = 23.17
# Product 23: Selected Slots = [7566], Influence = 20.75
# Product 24: Selected Slots = [7580], Influence = 20.75
# Product 25: Selected Slots = [7585], Influence = 23.34
# Product 26: Selected Slots = [7661], Influence = 7.78
# Product 27: Selected Slots = [7775], Influence = 23.34
# Product 28: Selected Slots = [7780], Influence = 16.14
# Product 29: Selected Slots = [7781], Influence = 18.44
# Product 30: Selected Slots = [2917], Influence = 6.54
# Product 31: Selected Slots = [7563], Influence = 14.12
# Product 32: Selected Slots = [7587], Influence = 12.10
# Product 33: Selected Slots = [7588], Influence = 14.12
# Product 34: Selected Slots = [7656], Influence = 6.05
# Product 35: Selected Slots = [7658], Influence = 8.07
# Product 36: Selected Slots = [7659], Influence = 4.03
# Product 37: Selected Slots = [7662], Influence = 8.07
# Product 38: Selected Slots = [7740], Influence = 12.10
# Product 39: Selected Slots = [1774], Influence = 4.00
# Product 40: Selected Slots = [1776], Influence = 4.00
# Product 41: Selected Slots = [1787, 1795], Influence = 6.00
# Product 42: Selected Slots = [1804], Influence = 4.00
# Product 43: Selected Slots = [1812], Influence = 4.00
# Product 44: Selected Slots = [1814], Influence = 4.00
# Product 45: Selected Slots = [1815], Influence = 4.00
# Product 46: Selected Slots = [1817, 1820], Influence = 6.00
# Product 47: Selected Slots = [1823], Influence = 4.00
# Product 48: Selected Slots = [1825], Influence = 4.00
# Product 49: Selected Slots = [1826], Influence = 4.00
# Product 50: Selected Slots = [1827], Influence = 4.00
# Product 51: Selected Slots = [1847], Influence = 4.00
# Product 52: Selected Slots = [1849, 1857], Influence = 8.00
# Product 53: Selected Slots = [1863], Influence = 4.00
# Product 54: Selected Slots = [1866, 1869], Influence = 8.00
# Product 55: Selected Slots = [1874], Influence = 4.00
# Product 56: Selected Slots = [1876, 1878], Influence = 8.00
# Product 57: Selected Slots = [1881], Influence = 4.00
# Product 58: Selected Slots = [1884], Influence = 4.00
# Product 59: Selected Slots = [1894], Influence = 4.00
# Product 60: Selected Slots = [1896, 2918], Influence = 5.78
# Product 61: Selected Slots = [7594, 9465], Influence = 10.41
# Product 62: Selected Slots = [7595], Influence = 8.64
# Product 63: Selected Slots = [7596], Influence = 5.19
# Product 64: Selected Slots = [7606], Influence = 10.37
# Product 65: Selected Slots = [7683], Influence = 10.37
# Product 66: Selected Slots = [7764], Influence = 8.64
# Product 67: Selected Slots = [7765], Influence = 10.37
# Product 68: Selected Slots = [7766], Influence = 10.37
# Product 69: Selected Slots = [7768], Influence = 10.37
# Product 70: Selected Slots = [7769], Influence = 10.37
# Product 71: Selected Slots = [7778], Influence = 10.37
# Product 72: Selected Slots = [7779], Influence = 8.64
# Product 73: Selected Slots = [7568], Influence = 7.20
# Product 74: Selected Slots = [7569], Influence = 7.20
# Product 75: Selected Slots = [7574], Influence = 7.20
# Product 76: Selected Slots = [7576], Influence = 7.20
# Product 77: Selected Slots = [7582], Influence = 7.20
# Product 78: Selected Slots = [7604], Influence = 7.20
# Product 79: Selected Slots = [7672], Influence = 7.20
# Product 80: Selected Slots = [7685], Influence = 5.76
# Product 81: Selected Slots = [7737], Influence = 7.20
# Product 82: Selected Slots = [7747], Influence = 7.20
# Product 83: Selected Slots = [7752], Influence = 4.32
# Product 84: Selected Slots = [7758], Influence = 5.76
# Product 85: Selected Slots = [7761], Influence = 5.76
# Product 86: Selected Slots = [7773], Influence = 7.20
# Product 87: Selected Slots = [9454], Influence = 5.54
# Product 88: Selected Slots = [9324], Influence = 13.53
# Product 89: Selected Slots = [6439, 9198], Influence = 7.50
# Product 90: Selected Slots = [7565], Influence = 4.61
# Product 91: Selected Slots = [7567], Influence = 4.61
# Product 92: Selected Slots = [7571], Influence = 4.61
# Product 93: Selected Slots = [7573], Influence = 4.61
# Product 94: Selected Slots = [7575], Influence = 4.61
# Product 95: Selected Slots = [7581], Influence = 4.61
# Product 96: Selected Slots = [7590], Influence = 4.61
# Product 97: Selected Slots = [7591], Influence = 4.61
# Product 98: Selected Slots = [7598], Influence = 4.61
# Product 99: Selected Slots = [7602], Influence = 4.61
# Product 100: Selected Slots = [7605], Influence = 4.61
#
# Total Selected Slots (unique): 113
# Total Combined Influence: 875.6470898064698
# Execution time: 0.38 seconds

# %%
h = len(Dem)
count = 0

for j in range(h):
    if influence(result[j]) >= Dem[j]:
        count += 1

print("Number of products whose demands are satisfied:", count, "out of", h)
# Out:
# Number of products whose demands are satisfied: 100 out of 100
